# %% [markdown]
# <a href="https://colab.research.google.com/github/kuonumber/crawler/blob/master/Day20_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# %% [markdown]
# ![Dcard_get_all_XHR_preview.png](data:image/png;base64,...)

# %% [markdown]
# ![Dcard_get_all_XHR_header.png](data:image/png;base64,...)

# %%
url ='https://www.dcard.tw/service/api/v2/popularForums/GetPage?pageKey=4783f687-b0d1-417e-a82c-b48d0c4c0d8b'
url ='https://www.dcard.tw/service/api/v2/popularForums/GetPage?pageKey=aaedd40f-dc79-445e-9ddb-ff12dfa47c1f'

# %%
r = requests.get(url)
d = json.loads(r.text)

# %%
d
# Out:
# {'items': [{'alias': 'movie',
#    'id': '275e0c11-82d0-43df-9606-502f5727716d',
#    'name': '電影',
#    'posts': [{'excerpt': '一直以來我都以為木須龍是男主角，木蘭是女主角，李翔的愛情元素根本不重要！！，1.沒有木須（吳宗憲），已不再歡樂，2.沒有幸運蟋蟀\U0001f997來襯托木須的主角特性，3.沒有找胡婷婷就是不看，4.沒有找胡婷婷就是',
#      'id': 234356456,
#      'title': '我拒看的原因很簡單'}]},
#   {'alias': 'marvel',
#    'id': '37a78696-f6a6-48ec-a19f-688f799a2aed',
#    'name': '靈異',
#    'posts': [{'excerpt': '從鬼門裡面出來的基本上有兩種靈魂，一種叫做等投胎的一般靈魂，一種叫做受刑中的罪魂。一般來說從外表看不出來，有家可以回去的就會回家看看，沒有家的就當放假出來走走。但無論是哪種，如果在放假的這段時間做了甚',
#      'id': 234362127,
#      'title': '普渡搶食畫面就像清倉大拍賣的太太們'}]},
#   {'alias': 'apple',
#    'id': '42bfdc63-8601-4e87-b53c-53d831caa2cf',
#    'name': 'Apple',
#    'posts': [{'excerpt': '大家好 今天來跟大家分享一下我使用剛到手不久的ipad pro+Apple Pencil 2的小小心得\U0001f970，因為已經有了mac book 所以買ipad的功能被我定位為「電子書」、「電子筆記」（「追劇',
#      'id': 234359927,
#      'title': 'IPad Pro+apple pencil 2 使用心得分享'}]},
#   {'alias': 'game',
#    'id': '72f262c4-75aa-4d75-ab0e-cd7bd09e69b5',
#    'name': '遊戲',
# ...
