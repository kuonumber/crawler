# %% [markdown]
# <a href="https://colab.research.google.com/github/kuonumber/crawler/blob/master/Day7_homewwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.（簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？
#
# [http缺點
# ](https://juejin.im/post/6844903630533836807)
#
#
#
# 1.   明碼容易被竊取資料
# 2.   資料無法驗證有無被竄改

# %% [markdown]
# 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。
# ![python-vs-javascript.jpg](data:image/jpeg;base64,...)
